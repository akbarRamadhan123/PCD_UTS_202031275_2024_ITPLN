# %%
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as img
import numpy as np

# %matplotlib inline

# %% [markdown]
# # Membaca Gambar

# %%
img = img.imread("akbar.jpg")
plt.imshow(img)

# %%
img.shape
# Out:
# (917, 1290, 3)

# %%
img_contrast = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %% [markdown]
# # Membuat Baris Dan Kolom

# %%
[baris, kolom] = img.shape[:2]

# %% [markdown]
# # 1. Deteksi Warna Pada Citra

# %% [markdown]
# ## Plot Warna

# %%
b = img[:,:,0]
g = img[:,:,1]
r = img[:,:,2]

# %%
# Membuat plot untuk setiap saluran warna
plt.figure(figsize=(12, 6))

# Plot saluran warna merah (R)
plt.subplot(141)
plt.imshow(img)
plt.title('Contrast')
plt.axis('off')

# Plot saluran warna merah (R)
plt.subplot(142)
plt.imshow(r, cmap='gray')
plt.title('(R)')
plt.axis('off')

# Plot saluran warna hijau (G)
plt.subplot(143)
plt.imshow(g, cmap='gray')
plt.title('(G)')
plt.axis('off')

# Plot saluran warna biru (B)
plt.subplot(144)
plt.imshow(b, cmap='gray')
plt.title('(B)')
plt.axis('off')

# Menampilkan plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Histogram

# %%
fig, axs = plt.subplots(2,2, figsize=(15,5))
axs[0,0].hist(img_contrast.ravel(), 256, [0,256])
axs[0, 0].set_title('Histogram Gambar Asli')


axs[0,1].hist(r.ravel(), 256, [0,256])
axs[0, 1].set_title('Histogram Red')


axs[1,0].hist(g.ravel(), 256, [0,256])
axs[1, 0].set_title('Histogram Green')


axs[1,1].hist(b.ravel(), 256, [0,256])
axs[1, 1].set_title('Histogram Blue')

plt.show()

# %% [markdown]
# # Batas Citra

# %%
img_akbar = cv2.imread('akbar.jpg')

hsv = cv2.cvtColor(img_akbar, cv2.COLOR_BGR2HSV)

l_biru = np.array([10,75,75])
u_biru = np.array([145,255,255])

l_hijau = np.array([5,50,50])
u_hijau = np.array([90,255,255])

l_merah = np.array([0,50,50])
u_merah = np.array([15,255,255])

l_merah_s = np.array([165,50,100])
u_merah_s = np.array([250,255,255])

biru_masking = cv2.inRange(hsv,l_biru,u_biru)
hijau_masking = cv2.inRange(hsv,l_hijau,u_hijau)

merah_masking = cv2.inRange(hsv,l_merah,u_merah)
merah_masking2 = cv2.inRange(hsv,l_merah_s,u_merah_s)
merah_masking = cv2.bitwise_or(merah_masking, merah_masking2)

# %%
plt.subplot(2,2,1)
plt.imshow(cv2.cvtColor(img_akbar, cv2.COLOR_BGR2RGB))
plt.title("Gambar Asli")

plt.subplot(2,2,2)
plt.imshow(merah_masking, cmap='gray')
plt.title("Merah")
           
plt.subplot(2,2,3)
plt.imshow(hijau_masking, cmap='gray')
plt.title("Hijau")
           
plt.subplot(2,2,4)
plt.imshow(biru_masking, cmap='gray')
plt.title("Biru")
# Out:
# Text(0.5, 1.0, 'Biru')
